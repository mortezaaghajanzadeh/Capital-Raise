# %%
import os
import pandas as pd
import numpy as np
import re

# %%
def convert_ar_characters(input_str):

    mapping = {
        'ك': 'ک',
        'گ':'گ',
        'دِ': 'د',
        'بِ': 'ب',
        'زِ': 'ز',
        'ذِ': 'ذ',
        'شِ': 'ش',
        'سِ': 'س',
        'ى': 'ی',
        'ي': 'ی'
    }
    return _multiple_replace(mapping, input_str)


def _multiple_replace(mapping, text):
    pattern = "|".join(map(re.escape, mapping.keys()))
    return re.sub(pattern, lambda m: mapping[m.group()], str(text))

# %%
path3 = r"G:\Hard Data\Capital Raise\\"
n8 = path3 + "Name-ISN-Code-Latinname-Symbol-Industry-Sub_industry.xlsx"
symbolfirm = pd.read_excel(n8)[['Symbol','Firm']]
symbolfirm['Symbol'] = symbolfirm['Symbol'].apply(lambda x: convert_ar_characters(x))
symbolfirm['Firm'] = symbolfirm['Firm'].apply(lambda x: convert_ar_characters(x))

# %%
path3 = r"G:\Hard Data\Capital Raise\\"
n8 = path3 + "FirmSymbol.xlsx"
symbolfirm1 = pd.read_excel(n8).rename(columns = {'name':'Symbol'})
symbolfirm1['Symbol'] = symbolfirm1['Symbol'].apply(lambda x: convert_ar_characters(x))
symbolfirm1['Firm'] = symbolfirm1['Firm'].apply(lambda x: convert_ar_characters(x))

# %%
symbolfirm = symbolfirm.append(symbolfirm1).drop_duplicates().reset_index(drop = True)
symbolfirm.loc[symbolfirm.Firm.str[-1] == " ",'Firm'] = symbolfirm.loc[symbolfirm.Firm.str[-1] == " "].Firm.str[:-1]

# %%
path1 = r"G:\Hard Data\Capital Raise\افزایش سرمایه\\"
n1 = path1 + "full share capital increase.xlsx"
df1 = pd.read_excel(n1)
df1 = df1[~df1['CapBefore'].isnull()]
df1.columns
ids = symbolfirm.Firm
mapingdict = dict(zip(symbolfirm.Firm, symbolfirm.Symbol))
df1['firm'] = df1['firm'].apply(lambda x: convert_ar_characters(x))
df1['Symbol'] = df1['firm'].map(mapingdict)
df1 = df1.sort_values(by = ['Symbol','ExtOrdGMDate'])
df1.loc[df1.year.isnull(),'year'] = df1[df1.year.isnull()]['ExtOrdGMDate'].str[:4]
df1 = df1.rename(columns = {'firm':'Firm'})

# %%
n2 = path1 + "capital raise - 89-92.xlsx"
df2 = pd.read_excel(n2) 
df2['Symbol'] = df2['Symbol'].apply(lambda x: convert_ar_characters(x))
df2['Firm'] = df2['Firm'].apply(lambda x: convert_ar_characters(x))
df2.columns
# Out:
# Index(['Firm', 'Symbol', 'CapBefore', 'ROCapRaising', '%ROCapRaising',
#        'SavingCapRaising', '%SavingCapRaising', 'CapAfter', 'FirstTrade'],
#       dtype='object')

# %%
df2.tail()
# Out:
#                               Firm  Symbol   CapBefore  ROCapRaising  \
# 179  سرمایه‌گذاری توسعه‌آذربایجان‌    وآذر     54700.0           NaN
# 180            فولاد مبارکه اصفهان   فولاد  15800000.0     7900000.0
# 181     توسعه‌ صنایع‌ بهشهر(هلدینگ   وبشهر   2160000.0      864000.0
# 182              بانک صادرات ایران  وبصادر  16803000.0           NaN
# 183          ذغال‌سنگ‌ نگین‌ ط‌بس‌    کطبس     30000.0           NaN
#
#      %ROCapRaising  SavingCapRaising  %SavingCapRaising    CapAfter  \
# 179            0.0           45300.0          82.815356    100000.0
# 180           50.0         2100000.0          13.291139  25800000.0
# 181           40.0               NaN           0.000000   3024000.0
# 182            0.0         3360600.0          20.000000  20163600.0
# 183            0.0           30000.0         100.000000     60000.0
#
#      FirstTrade
# 179  1389/11/27
# 180  1389/11/30
# 181  1389/11/30
# 182  1389/12/18
# 183  1389/12/24

# %%
n3 = path1 + "ƒnd ƒs¬ƒn¼ ½¬Oƒn8 8ƒ ƒ¬ ½ƒnó FºƒT ƒ½óª¬ƒñ ¼º8.xlsx"
df3 = pd.read_excel(n3) 
df3['Symbol'] = df3['Symbol'].apply(lambda x: convert_ar_characters(x))
df3['Firm'] = df3['Firm'].apply(lambda x: convert_ar_characters(x))
df3.columns
df3.head()
# Out:
#   Symbol        Firm  CapBefore  CapAfter ExtOrdGMDate ExtOrdBoardDate  \
# 0  چافست        افست    20000.0   50000.0   1385/04/20             NaN
# 1  دالبر  البرز دارو    16000.0   48000.0   1386/02/19      1386/05/13
# 2  دالبر  البرز دارو    48000.0   72000.0   1388/04/06             NaN
# 3  دالبر  البرز دارو    72000.0  100000.0   1389/04/12             NaN
# 4  دالبر  البرز دارو   100000.0  125000.0   1390/02/10             NaN
#
#       RegDate SubsOpenDate SubsCloseDate SubsExtendedCloseDate  ROCapRaising  \
# 0  1385/06/14          NaN           NaN                   NaN           NaN
# 1  1386/06/10          NaN           NaN                   NaN  3.200000e+10
# 2  1388/09/11   1388/05/05    1388/07/05                   NaN  2.400000e+10
# 3  1389/09/29   1389/05/14    1389/07/11                   NaN  2.800000e+10
# 4  1390/06/03   1390/02/22    1390/04/19                   NaN  2.500000e+10
#
#    PremiumCapRaising  SavedDevelopmentPlanCapRaising  SavedSafetyCapRaising
# 0                NaN                             NaN                    NaN
# 1                0.0                             0.0                    0.0
# 2                0.0                             0.0                    0.0
# 3                0.0                             0.0                    0.0
# 4                0.0                             0.0                    0.0

# %%
n4 = path1 + "Share Capital Increase - 970715.xlsx"
df4 = pd.read_excel(n4) 

df4 = df4.sort_values(by =['Symbol','RegDate'])
df4['Symbol'] = df4['Symbol'].apply(lambda x: convert_ar_characters(x))
df4.columns
# Out:
# Index(['Symbol', 'RegDate', 'ExtOrdGMDate', 'CapRaised', 'CapAfter',
#        'ROCapRaising', 'PremiumCapRaising', 'SavingCapRaising'],
#       dtype='object')

# %%
n5 = path1 + "Shareholders' Capital-82-92.xlsx"
df5 = pd.read_excel(n5) 
df5['Firm'] = np.nan
df5.loc[df5.ExtOrdGMDate.str.contains("شرکت"),'Firm']= df5.loc[df5.ExtOrdGMDate.str.contains("شرکت")].ExtOrdGMDate.str[5:]
df5.Firm = df5.Firm.fillna(method='ffill')
df5 = df5.drop(df5.loc[df5.ExtOrdGMDate.str.contains("شرکت")].index)
df5 = df5[[ 'Firm','ExtOrdGMDate', 'GMType', 'BookValue', 'CapBefore', 'CapAfter',
       'CapRaised', '%CapRaised', '%SavingCapRaising', '%ROCapRaising',
       '%PremiumCapRaising', 'PriceBMG', 'PriceAMG', 'SubsCloseDate',
       'RegDate']]
df5.columns
df5.Firm =  df5.Firm.str[1::]
ids = symbolfirm.Firm
mapingdict = dict(zip(symbolfirm.Firm, symbolfirm.Symbol))
df5['Firm'] = df5['Firm'].apply(lambda x: convert_ar_characters(x))
df5['Symbol'] = df5['Firm'].map(mapingdict)
df5.head()
# Out:
#                     Firm ExtOrdGMDate      GMType  BookValue  CapBefore  \
# 1                  آ.س.پ   1388/11/10        مجمع     1000.0    60000.0
# 2                  آ.س.پ   1389/12/08        مجمع     1000.0   120000.0
# 4    صنایع شیمیایی ایران   1391/12/15        مجمع     1000.0   257166.0
# 5    صنایع شیمیایی ایران   1391/12/26  هیئت مدیره     1000.0   257166.0
# 7  صنایع ریخته گری ایران   1386/03/26        مجمع     1000.0    10000.0
#
#    CapAfter  CapRaised  %CapRaised  %SavingCapRaising  %ROCapRaising  \
# 1  120000.0    60000.0      100.00                0.0          100.0
# 2  200000.0    80000.0       66.67                0.0          100.0
# 4  257166.0        0.0        0.00                0.0            0.0
# 5  771498.0   514332.0      200.00              100.0            0.0
# 7   23607.0    13607.0      136.07              100.0            0.0
#
#    %PremiumCapRaising  PriceBMG  PriceAMG SubsCloseDate     RegDate Symbol
# 1                 0.0       NaN    3100.0           NaN  1389/01/17  آ س پ
# 2                 0.0       NaN    3100.0           NaN         NaN  آ س پ
# 4                 0.0       NaN       NaN           NaN         NaN  شیران
# 5                 0.0   49940.0   23544.0           NaN  1392/02/18  شیران
# 7                 0.0    8022.0    3400.0           NaN  1386/05/01  خریخت

# %%
path2 = r"G:\Hard Data\Capital Raise\Share Capital Increase\\"
n6 = path2 + "Shareholders' Capital-84-97.xlsx"

df6 = pd.read_excel(n6)
df6['Symbol'] = df6['Symbol'].apply(lambda x: convert_ar_characters(x))
df6.head()
# Out:
#    ROCapRaising  SavingCapRaising     RegDate ExtOrdGMDate   CapAfter  \
# 0        600000                 0  1393/12/10   1393/02/09   800000.0
# 1             0                 0  1384/10/12   1382/11/26    16800.0
# 2   16800000000                 0  1386/11/30          NaN    33600.0
# 3        600000                 0  1393/05/20   1392/04/02  1200000.0
# 4        910800                 0  1392/04/31   1391/12/22  9190800.0
#
#    CapBefore  PremiumCapRaising Symbol
# 0   200000.0                  0  آ س پ
# 1    13800.0                  0   آبفر
# 2    16800.0                  0   آبفر
# 3   600000.0                  0  آرمان
# 4  8280000.0                  0  آریان

# %%
path3 = r"G:\Hard Data\Capital Raise\Rights Offerings\\"
n3 = path3 + "Rights Offerings 1389 to 1397.xlsx"
df7 = pd.DataFrame()
for i in range(1383,1398):
    print(i)
    t = pd.read_excel(n3, str(i))
    df7 = df7.append(t)
df7 = df7[[ 'symbol', 'ExtOrdGMInvDate','ExtOrdGMDate','CapAfter', 'CapBefore',
           'CapRaised', 'Costs', 'ExRightsNo','GenSubsRightsNo', 'IPODate',
       'LicenseDate', 'MktOfferCloseDate', 'MktOfferOpenDate', 'NetCashUnEx',
       'OnlyRO', 'PreviousRODate', 'ROCapRaising', 'PremiumCapRaising', 'RegDate',
       'SubsCloseDate', 'SubsOpenDate', 'TotUnExRev', 'UnExRightsNo',
       'financial_firm', 'fiscal_year', 'group_en_name', 'group_id',
       'group_name', 'market', 'market_en', 'perShareNetCashUnEx']]

df7 = df7.sort_values(by = ['symbol','ExtOrdGMDate']).rename(columns = {'symbol':'Symbol'})
# Out:
# 1383
# 1384
# 1385
# 1386
# 1387
# 1388
# 1389
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# 1390
# 1391
# 1392
# 1393
# 1394
# 1395
# 1396
# 1397

# %%
df1 = df1[['Symbol','Firm', 'year', 'ExtOrdGMDate', 'GMType', 'BookValue', 'CapBefore', 'CapAfter',
       'CapRaised', '%CapRaised', '%SavingCapRaising', 'SavingCapRaising',
       '%ROCapRaising', 'ROCapRaising', '%PremiumCapRaising',
       'PremiumCapRaising', 'SubsCloseDate']].reset_index(drop = True)

# %%
df7 = df7[['Symbol', 'ExtOrdGMInvDate', 'ExtOrdGMDate', 'CapAfter', 'CapBefore',
       'CapRaised', 'Costs', 'ExRightsNo', 'GenSubsRightsNo',
       'LicenseDate', 'MktOfferCloseDate', 'MktOfferOpenDate', 'NetCashUnEx',
       'OnlyRO','ROCapRaising', 'PremiumCapRaising', 'RegDate',
       'SubsCloseDate', 'SubsOpenDate', 'TotUnExRev', 'UnExRightsNo', 'perShareNetCashUnEx']].reset_index(drop = True)

# %%
df1['file'] = 1
df2['file'] = 2
df3['file'] = 3
df4['file'] = 4
df5['file'] = 5
df6['file'] = 6
df7['file'] = 7

# %%
df = df1.append(df2).append(df3).append(df4).append(df5).append(df6).append(df7).sort_values(by = ['Symbol','ExtOrdGMDate'])
df.Firm = df.Firm.str.replace("سر.","سرمایه گذاری")
df.loc[df.year.isnull(),'year'] = df[df.year.isnull()]['ExtOrdGMDate'].str[:4]
df.Symbol = df.Symbol.replace(np.nan, '')
df.loc[df.Symbol.str.contains("\("),'Symbol'] = df[df.Symbol.str.contains("\(")]['Symbol'].str.split("\(", n = 1, expand = True)[0] 
df.Symbol = df.Symbol.replace('', np.nan)
df.year = df.year.replace(np.nan,0)
df.year = df.year.astype(int)
df.year = df.year.replace(0,np.nan)
tt = df
df = df.sort_values(by = ['Symbol','year','file']).drop_duplicates(['year','Symbol','CapAfter','CapBefore'],keep = 'first')
df = df[(~df.CapBefore.isnull())&(~df.CapAfter.isnull())].reset_index(drop = True)
df = df[(~df.year.isnull())].reset_index(drop = True)
df.loc[df.Firm == 'ص مهندسی فیروزا','Firm'] = "مهندسی فیروزا"
df.loc[df.Firm == 'س.ص. بازنشستگی کارکنان بانکها','Firm'] = "س.ص.بازنشستگی کارکنان بانکها"
df.loc[df.Firm == 'پیام','Firm'] = "صنعتی پیام"
df.loc[df.Firm == 'پیوند گستر پارس','Firm'] = "برق و انرژی پیوندگستر پارس"
df.loc[df.Firm == 'توسعه بین الملی پدیده شاندیز','Firm'] = "توسعه بین المللی پدیده شاندیز"
df.loc[df.Firm == 'لیزینگ ایران و شرق','Firm'] = "لیزینگ ایران و شرق"
df.loc[df.Firm == 'سرمایه گذاری نفت و گاز و پتروشیمی تامین','Firm'] = "سر. نفت و گاز تامین"
df.loc[df.Firm == 'دارو داملران رازک','Firm'] = "دارو رازک"
df.loc[df.Firm == 'موسسه مالی و اعتباری قوامین','Firm'] = "بانک قوامین"
df.loc[df.Firm == 'بوتان','Firm'] = "صنعتی بوتان"
df.loc[df.Firm == 'زر ماکارون','Firm'] = "صنعتی زر ماکارون"
df.loc[df.Firm == 'مالی اعتباری کوثر مرکزی','Firm'] = "اعتباری کوثر مرکزی"
df.loc[df.Firm == 'تاید واتر','Firm'] = "تایدواترخاورمیانه"
df.loc[df.Firm == 'مپنا (نیروگاهی ایران)','Firm'] = "گروه مپنا"
df.loc[df.Firm == 'دنا آفرین فدک','Firm'] = "تهیه توزیع غذای دنا آفرین فدک"
df.loc[df.Firm == 'کود شیمیائی اوره لردگان','Firm'] = "کود شیمیایی اوره لردگان"
df.loc[df.Firm == 'شیر پاستوریزه پگاه گیلان','Firm'] = "شیرپاستوریزه پگاه گیلان"
df.loc[df.Firm == 'فولاد سپید فراب کویر','Firm'] = "تولیدی فولاد سپید فراب کویر"
df.loc[df.Firm == 'چین چین','Firm'] = "کشت‌ و صنعت‌ چین‌ چین"
df.loc[df.Firm == 'لیزینگ ایران و شرق ','Firm'] = "لیزینگ ایران و شرق"
df.loc[df.Firm == 'سرمایه گذاری صندوق بازنشستگی کارکنان بانکها','Firm'] = "س.ص.بازنشستگی کارکنان بانکها"
mapingdict = dict(zip(symbolfirm.Firm, symbolfirm.Symbol))
df['Symbol2'] = df['Firm'].map(mapingdict)
df['Symbol1'] = np.nan
df.loc[~df.Symbol.isnull(),'Symbol1'] = df.loc[~df.Symbol.isnull()].Symbol
df.loc[~df.Symbol2.isnull(),'Symbol1'] = df.loc[~df.Symbol2.isnull()].Symbol2
df = df.drop(columns = ['Symbol','Symbol2']).rename(columns = {'Symbol1':'Symbol'})
df.loc[df.Firm == 'سرمایه گذاری کشاورزی کوثر','Symbol'] = "زکوثر"
df.loc[df.Firm == 'صنعتی و معدنی ستبران','Symbol'] = "ستبرا"

df.loc[df.Firm == 'سیمان سفیدنی ریز','Symbol'] = "سنیر"
df.loc[df.Firm == 'تامین مواد اولیه فولاد صبانور','Symbol'] = "کنور"
df.loc[df.Firm == 'کیا الکترود شرق','Symbol'] = "کیا"
df.loc[df.Symbol.str[-1] == " ",'Symbol'] = df.loc[df.Symbol.str[-1] == " "].Symbol.str[:-1]
df.loc[df.Symbol.str[0] == " ",'Symbol'] = df.loc[df.Symbol.str[0] == " "].Symbol.str[1:]

# %%
df
# Out:
#         %CapRaised  %PremiumCapRaising  %ROCapRaising  %SavingCapRaising  \
# 0     1.000000e+02                 0.0     100.000000           0.000000
# 1     1.000000e+02                 0.0     100.000000           0.000000
# 2     6.666667e+01                 0.0     100.000000           0.000000
# 3     0.000000e+00                 0.0       0.000000           0.000000
# 4     3.000000e+02                 0.0     100.000000           0.000000
# 5     0.000000e+00                 0.0       0.000000           0.000000
# 6              NaN                 NaN            NaN                NaN
# 7     1.250000e+01                 0.0     100.000000           0.000000
# 8     0.000000e+00                 0.0       0.000000           0.000000
# 9     1.111111e+01                 0.0     100.000000           0.000000
# 10             NaN                 NaN            NaN                NaN
# 11    1.500000e+01                 0.0     100.000000           0.000000
# 12    1.500000e+01                 0.0     100.000000           0.000000
# 13    2.173913e+01                 0.0       0.000000         100.000000
# 14    1.000000e+02                 0.0     100.000000           0.000000
# 15    1.000000e+02                 0.0     100.000000           0.000000
# 16    0.000000e+00                 0.0       0.000000           0.000000
# 17    2.500000e+01                 0.0     100.000000           0.000000
# 18    6.000000e+01                 0.0     100.000000           0.000000
# 19    2.500000e+00                 0.0     100.000000           0.000000
# 20    7.086220e+03                 0.0       0.000000         100.000000
# 21    0.000000e+00                 0.0       0.000000           0.000000
# 22    5.118129e+02                 0.0       0.000000         100.000000
# 23    0.000000e+00                 0.0       0.000000           0.000000
# 24    5.384615e+01                 0.0     100.000000           0.000000
# 25    0.000000e+00                 0.0       0.000000           0.000000
# 26    0.000000e+00                 0.0       0.000000           0.000000
# 27             NaN                 NaN            NaN                NaN
# 28    1.000000e+02                 0.0     100.000000           0.000000
# 29    0.000000e+00                 0.0       0.000000           0.000000
# ...            ...                 ...            ...                ...
# 6937  2.000000e+02                 0.0       0.000000         100.000000
# 6938  6.000000e+01                 0.0       0.000000         100.000000
# 6939  2.999900e+06               100.0       0.000000           0.000000
# 6940  1.062706e+02               100.0       0.000000           0.000000
# 6941  8.040000e+00               100.0       0.000000           0.000000
# 6942  0.000000e+00                 0.0       0.000000           0.000000
# 6943  1.222222e+02                 0.0     100.000000           0.000000
# 6944  1.307692e+02                 0.0     100.000000           0.000000
# 6945  0.000000e+00                 0.0       0.000000           0.000000
# 6946  0.000000e+00                 0.0       0.000000           0.000000
# 6947  1.823529e+02               100.0       0.000000           0.000000
# 6948  6.250000e+01                 0.0     100.000000           0.000000
# 6949  0.000000e+00                 0.0       0.000000           0.000000
# 6950  0.000000e+00                 0.0       0.000000           0.000000
# 6951  6.666667e+01                 0.0     100.000000           0.000000
# 6952  4.285714e+01                 0.0      33.333333          66.666667
# 6953  1.051282e+02                 0.0     100.000000           0.000000
# 6954  9.352000e-01                 0.0       0.000000         100.000000
# 6955  2.307692e+01                 0.0     100.000000           0.000000
# 6956  3.000000e+02                 0.0       0.000000         100.000000
# 6957  5.000000e+01               100.0       0.000000           0.000000
# 6958  0.000000e+00                 0.0       0.000000           0.000000
# 6959  3.636364e+01                 0.0     100.000000           0.000000
# 6960  2.000000e+01                 0.0       0.000000         100.000000
# 6961  3.622601e+01                 0.0       0.000000         100.000000
# 6962  0.000000e+00                 0.0       0.000000           0.000000
# 6963  5.000000e+01                 0.0       0.000000         100.000000
# 6964  3.072566e+02                 0.0       0.000000         100.000000
# 6965  0.000000e+00                 0.0       0.000000           0.000000
# 6966  2.000000e+02                 0.0     100.000000           0.000000
#
#       BookValue      CapAfter   CapBefore     CapRaised      Costs  \
# 0        1000.0  1.200000e+05     60000.0  6.000000e+04        NaN
# 1        1000.0  1.200000e+05     60000.0  6.000000e+04        NaN
# 2        1000.0  2.000000e+05    120000.0  8.000000e+04        NaN
# 3        1000.0  2.000000e+05    200000.0  0.000000e+00        NaN
# 4        1000.0  8.000000e+05    200000.0  6.000000e+05        NaN
# 5        1000.0  8.000000e+05    800000.0  0.000000e+00        NaN
# 6           NaN  9.000000e+05    800000.0  1.000000e+05  483891976
# 7        1000.0  9.000000e+05    800000.0  1.000000e+05        NaN
# 8        1000.0  9.000000e+05    900000.0  0.000000e+00        NaN
# 9        1000.0  1.000000e+06    900000.0  1.000000e+05        NaN
# 10          NaN  1.680000e+04     13800.0           NaN        NaN
# 11       1000.0  1.380000e+04     12000.0  1.800000e+03        NaN
# 12       1000.0  1.380000e+04     12000.0  1.800000e+03        NaN
# 13       1000.0  1.680000e+04     13800.0  3.000000e+03        NaN
# 14       1000.0  3.360000e+04     16800.0  1.680000e+04        NaN
# 15       1000.0  3.360000e+04     16800.0  1.680000e+04        NaN
# 16       1000.0  2.000000e+03      2000.0  0.000000e+00        NaN
# 17       1000.0  2.500000e+03      2000.0  5.000000e+02        NaN
# 18       1000.0  4.000000e+03      2500.0  1.500000e+03        NaN
# 19       1000.0  4.100000e+03      4000.0  1.000000e+02        NaN
# 20       1000.0  2.946350e+05      4100.0  2.905350e+05        NaN
# 21       1000.0  2.946350e+05    294635.0  0.000000e+00        NaN
# 22       1000.0  1.802615e+06    294635.0  1.507980e+06        NaN
# 23       1000.0  1.250000e+04     12500.0  0.000000e+00        NaN
# 24       1000.0  6.000000e+05    390000.0  2.100000e+05        NaN
# 25       1000.0  6.000000e+05    600000.0  0.000000e+00        NaN
# 26       1000.0  1.200000e+06   1200000.0  0.000000e+00        NaN
# 27          NaN  1.200000e+06    600000.0           NaN        NaN
# 28       1000.0  1.200000e+06    600000.0  6.000000e+05        NaN
# 29       1000.0  1.200000e+06   1200000.0  0.000000e+00        NaN
# ...         ...           ...         ...           ...        ...
# 6937     1000.0  9.000000e+05    300000.0  6.000000e+05        NaN
# 6938     1000.0  8.000000e+05    500000.0  3.000000e+05        NaN
# 6939     1000.0  3.000000e+05        10.0  2.999900e+05        NaN
# 6940     1000.0  5.000000e+03      2424.0  2.576000e+03        NaN
# 6941     1000.0  2.701000e+06   2500000.0  2.010000e+05        NaN
# 6942     1000.0  1.614680e+05    161468.0  0.000000e+00        NaN
# 6943     1000.0  2.000000e+06    900000.0  1.100000e+06        NaN
# 6944     1000.0  1.200000e+05     52000.0  6.800000e+04        NaN
# 6945     1000.0  1.000000e+07  10000000.0  0.000000e+00        NaN
# 6946     1000.0  2.000000e+04     20000.0  0.000000e+00        NaN
# 6947     1000.0  2.400000e+06    850000.0  1.550000e+06        NaN
# 6948     1000.0  1.300000e+06    800000.0  5.000000e+05        NaN
# 6949     1000.0  3.500000e+06   3500000.0  0.000000e+00        NaN
# 6950     1000.0  1.000000e+05    100000.0  0.000000e+00        NaN
# 6951     1000.0  2.000000e+05    120000.0  8.000000e+04        NaN
# 6952     1000.0  5.000000e+06   3500000.0  1.500000e+06        NaN
# 6953     1000.0  8.000000e+07  39000000.0  4.100000e+07        NaN
# 6954     1000.0  2.018704e+06   2000000.0  1.870400e+04        NaN
# 6955     1000.0  1.600000e+06   1300000.0  3.000000e+05        NaN
# 6956     1000.0  4.000000e+05    100000.0  3.000000e+05        NaN
# 6957     1000.0  6.000000e+05    400000.0  2.000000e+05        NaN
# 6958     1000.0  5.000000e+06   5000000.0  0.000000e+00        NaN
# 6959     1000.0  1.500000e+07  11000000.0  4.000000e+06        NaN
# 6960     1000.0  6.000000e+06   5000000.0  1.000000e+06        NaN
# 6961     1000.0  2.750000e+06   2018704.0  7.312960e+05        NaN
# 6962     1000.0  2.400000e+06   2400000.0  0.000000e+00        NaN
# 6963     1000.0  3.600000e+06   2400000.0  1.200000e+06        NaN
# 6964     1000.0  1.100000e+07   2701000.0  8.299000e+06        NaN
# 6965     1000.0  3.600000e+06   3600000.0  0.000000e+00        NaN
# 6966     1000.0  1.080000e+07   3600000.0  7.200000e+06        NaN
#
#        ExRightsNo  ... SavingCapRaising SubsCloseDate SubsExtendedCloseDate  \
# 0             NaN  ...              NaN           NaN                   NaN
# 1             NaN  ...     0.000000e+00           NaN                   NaN
# 2             NaN  ...     0.000000e+00           NaN                   NaN
# 3             NaN  ...              NaN           NaN                   NaN
# 4             NaN  ...     0.000000e+00    1393/05/12                   NaN
# 5             NaN  ...              NaN           NaN                   NaN
# 6     8.62154e+07  ...              NaN    1397/11/14                   NaN
# 7             NaN  ...     0.000000e+00    1397/11/14                   NaN
# 8             NaN  ...              NaN           NaN                   NaN
# 9             NaN  ...     0.000000e+00    1399/02/15                   NaN
# 10            NaN  ...              NaN           NaN                   NaN
# 11            NaN  ...              NaN    1383/02/26                   NaN
# 12            NaN  ...     0.000000e+00    1383/02/26                   NaN
# 13            NaN  ...     3.000000e+03           NaN                   NaN
# 14            NaN  ...              NaN    1386/02/24                   NaN
# 15            NaN  ...     0.000000e+00    1386/02/24                   NaN
# 16            NaN  ...              NaN           NaN                   NaN
# 17            NaN  ...     0.000000e+00           NaN                   NaN
# 18            NaN  ...     0.000000e+00           NaN                   NaN
# 19            NaN  ...     0.000000e+00           NaN                   NaN
# 20            NaN  ...     2.905350e+05           NaN                   NaN
# 21            NaN  ...              NaN           NaN                   NaN
# 22            NaN  ...     1.507980e+06           NaN                   NaN
# 23            NaN  ...              NaN           NaN                   NaN
# 24            NaN  ...     0.000000e+00    1390/05/17                   NaN
# 25            NaN  ...              NaN           NaN                   NaN
# 26            NaN  ...              NaN           NaN                   NaN
# 27            NaN  ...     0.000000e+00           NaN                   NaN
# 28            NaN  ...     0.000000e+00    1392/07/25                   NaN
# 29            NaN  ...              NaN           NaN                   NaN
# ...           ...  ...              ...           ...                   ...
# 6937          NaN  ...     6.000000e+05           NaN                   NaN
# 6938          NaN  ...     3.000000e+05           NaN                   NaN
# 6939          NaN  ...     0.000000e+00           NaN                   NaN
# 6940          NaN  ...     0.000000e+00           NaN                   NaN
# 6941          NaN  ...     0.000000e+00           NaN                   NaN
# 6942          NaN  ...              NaN           NaN                   NaN
# 6943          NaN  ...     0.000000e+00    1396/10/17                   NaN
# 6944          NaN  ...     0.000000e+00    1396/12/02                   NaN
# 6945          NaN  ...              NaN           NaN                   NaN
# 6946          NaN  ...              NaN           NaN                   NaN
# 6947          NaN  ...     0.000000e+00           NaN                   NaN
# 6948          NaN  ...     0.000000e+00    1397/07/02                   NaN
# 6949          NaN  ...              NaN           NaN                   NaN
# 6950          NaN  ...              NaN           NaN                   NaN
# 6951          NaN  ...     0.000000e+00    1398/01/29                   NaN
# 6952          NaN  ...     1.000000e+06    1397/08/22                   NaN
# 6953          NaN  ...     0.000000e+00    1398/05/29                   NaN
# 6954          NaN  ...     1.870400e+04           NaN                   NaN
# 6955          NaN  ...     0.000000e+00    1398/08/28                   NaN
# 6956          NaN  ...     3.000000e+05           NaN                   NaN
# 6957          NaN  ...     0.000000e+00           NaN                   NaN
# 6958          NaN  ...              NaN           NaN                   NaN
# 6959          NaN  ...     0.000000e+00    1398/10/22                   NaN
# 6960          NaN  ...     1.000000e+06           NaN                   NaN
# 6961          NaN  ...     7.312960e+05           NaN                   NaN
# 6962          NaN  ...              NaN           NaN                   NaN
# 6963          NaN  ...     1.200000e+06           NaN                   NaN
# 6964          NaN  ...     8.299000e+06           NaN                   NaN
# 6965          NaN  ...              NaN           NaN                   NaN
# 6966          NaN  ...     0.000000e+00    1399/07/17                   NaN
#
#      SubsOpenDate   TotUnExRev UnExRightsNo file perShareNetCashUnEx    year  \
# 0             NaN          NaN          NaN    5                 NaN  1388.0
# 1             NaN          NaN          NaN    1                 NaN  1389.0
# 2             NaN          NaN          NaN    1                 NaN  1389.0
# 3             NaN          NaN          NaN    1                 NaN  1392.0
# 4             NaN          NaN          NaN    1                 NaN  1393.0
# 5             NaN          NaN          NaN    1                 NaN  1397.0
# 6      1397/09/15  11850676752     13784594    7             824.601  1397.0
# 7             NaN          NaN          NaN    1                 NaN  1398.0
# 8             NaN          NaN          NaN    1                 NaN  1398.0
# 9             NaN          NaN          NaN    1                 NaN  1398.0
# 10            NaN          NaN          NaN    3                 NaN  1382.0
# 11            NaN          NaN          NaN    5                 NaN  1382.0
# 12            NaN          NaN          NaN    1                 NaN  1383.0
# 13            NaN          NaN          NaN    1                 NaN  1384.0
# 14            NaN          NaN          NaN    5                 NaN  1385.0
# 15            NaN          NaN          NaN    1                 NaN  1386.0
# 16            NaN          NaN          NaN    1                 NaN  1379.0
# 17            NaN          NaN          NaN    1                 NaN  1382.0
# 18            NaN          NaN          NaN    1                 NaN  1383.0
# 19            NaN          NaN          NaN    1                 NaN  1386.0
# 20            NaN          NaN          NaN    1                 NaN  1391.0
# 21            NaN          NaN          NaN    1                 NaN  1399.0
# 22            NaN          NaN          NaN    1                 NaN  1399.0
# 23            NaN          NaN          NaN    1                 NaN  1383.0
# 24            NaN          NaN          NaN    1                 NaN  1390.0
# 25            NaN          NaN          NaN    1                 NaN  1392.0
# 26            NaN          NaN          NaN    1                 NaN  1392.0
# 27            NaN          NaN          NaN    6                 NaN  1392.0
# 28            NaN          NaN          NaN    1                 NaN  1393.0
# 29            NaN          NaN          NaN    1                 NaN  1396.0
# ...           ...          ...          ...  ...                 ...     ...
# 6937          NaN          NaN          NaN    1                 NaN  1395.0
# 6938          NaN          NaN          NaN    1                 NaN  1395.0
# 6939          NaN          NaN          NaN    1                 NaN  1395.0
# 6940          NaN          NaN          NaN    1                 NaN  1395.0
# 6941          NaN          NaN          NaN    1                 NaN  1396.0
# 6942          NaN          NaN          NaN    1                 NaN  1396.0
# 6943          NaN          NaN          NaN    1                 NaN  1396.0
# 6944          NaN          NaN          NaN    1                 NaN  1396.0
# 6945          NaN          NaN          NaN    1                 NaN  1396.0
# 6946          NaN          NaN          NaN    1                 NaN  1397.0
# 6947          NaN          NaN          NaN    1                 NaN  1397.0
# 6948          NaN          NaN          NaN    1                 NaN  1397.0
# 6949          NaN          NaN          NaN    1                 NaN  1397.0
# 6950          NaN          NaN          NaN    1                 NaN  1397.0
# 6951          NaN          NaN          NaN    1                 NaN  1397.0
# 6952          NaN          NaN          NaN    1                 NaN  1398.0
# 6953          NaN          NaN          NaN    1                 NaN  1398.0
# 6954          NaN          NaN          NaN    1                 NaN  1398.0
# 6955          NaN          NaN          NaN    1                 NaN  1398.0
# 6956          NaN          NaN          NaN    1                 NaN  1398.0
# 6957          NaN          NaN          NaN    1                 NaN  1398.0
# 6958          NaN          NaN          NaN    1                 NaN  1398.0
# 6959          NaN          NaN          NaN    1                 NaN  1398.0
# 6960          NaN          NaN          NaN    1                 NaN  1398.0
# 6961          NaN          NaN          NaN    1                 NaN  1398.0
# 6962          NaN          NaN          NaN    1                 NaN  1398.0
# 6963          NaN          NaN          NaN    1                 NaN  1399.0
# 6964          NaN          NaN          NaN    1                 NaN  1399.0
# 6965          NaN          NaN          NaN    1                 NaN  1399.0
# 6966          NaN          NaN          NaN    1                 NaN  1399.0
#
#          Symbol
# 0         آ س پ
# 1         آ س پ
# 2         آ س پ
# 3         آ س پ
# 4         آ س پ
# 5         آ س پ
# 6         آ س پ
# 7         آ س پ
# 8         آ س پ
# 9         آ س پ
# 10         آبفر
# 11         آبفر
# 12         آبفر
# 13         آبفر
# 14         آبفر
# 15         آبفر
# 16         آبین
# 17         آبین
# 18         آبین
# 19         آبین
# 20         آبین
# 21         آبین
# 22         آبین
# 23    آرد تجارت
# 24        آرمان
# 25        آرمان
# 26        آرمان
# 27        آرمان
# 28        آرمان
# 29        آرمان
# ...         ...
# 6937      زکوثر
# 6938        غزر
# 6939       گدنا
# 6940      ستبرا
# 6941       سیتا
# 6942        کیا
# 6943      زکوثر
# 6944      غگیلا
# 6945        NaN
# 6946      ستبرا
# 6947       کویر
# 6948        غزر
# 6949      وسکاب
# 6950       وآوا
# 6951      غگیلا
# 6952      وسکاب
# 6953       شستا
# 6954      زکوثر
# 6955        غزر
# 6956       وآوا
# 6957       وآوا
# 6958      وسکاب
# 6959        صبا
# 6960      وسکاب
# 6961      زکوثر
# 6962       کویر
# 6963       کویر
# 6964       سیتا
# 6965       کویر
# 6966       کویر
#
# [6967 rows x 39 columns]

# %%
def vv2(row):
    X = row.split('/')
    return int(X[0]+X[1]+X[2])

df.ExtOrdGMDate = df.ExtOrdGMDate.apply(vv2)
df = df.sort_values(by = ['Symbol','file','ExtOrdGMDate'])
df = df.drop(columns = ['file'])

df['CapBefore2'] = (df['CapBefore'] / 100).round(0)
df['CapAfter2'] = (df['CapAfter'] / 100).round(0)
df['ExtOrdGMDate2'] = (df['ExtOrdGMDate'] / 10).round(0)

df = df.drop_duplicates(subset=['Symbol','CapAfter2','CapBefore2'],keep = 'first')


df = df[df.CapBefore != 0]
df['Percent'] = ((df['CapAfter'] - df['CapBefore'])/df['CapBefore'] )* 100
df['Percent'] = df['Percent'].round(2)
df['year'] = df['ExtOrdGMDate']/10000
df['year'] = df['year'].round(0)


df = df.drop_duplicates(subset=['ExtOrdGMDate','Symbol'],keep = 'first')


df = df.sort_values(by = ['Symbol','Firm','ExtOrdGMDate'])
df.head()

df = df.reset_index(drop = True)
# df['Revaluation'] = 0 
# def reval(g):
#     g.loc[g.index.isin(g[(g.CapAfter == g.CapBefore)].index + 1),'Revaluation'] = 1
#     return g
# df  = df.groupby('Symbol').apply(reval)

df['JustRO'] = 0
df.loc[df['%ROCapRaising'] == 100,'JustRO'] = 1
df['JustSaving'] = 0
df.loc[df['%SavingCapRaising'] == 100,'JustSaving'] = 1
df['JustPremium'] = 0
df.loc[df['%PremiumCapRaising'] == 100,'JustPremium'] = 1
df['Hybrid'] = 0
df.loc[(df['%PremiumCapRaising'] != 100)&(df['%SavingCapRaising'] != 100)&(df['%ROCapRaising'] != 100),
       'Hybrid'] = 1

df = df[['Symbol', 'year','Firm', 'CapAfter', 'CapBefore', 'ExtOrdGMDate',
         'JustRO','JustSaving','JustPremium','Hybrid','%CapRaised',
         '%PremiumCapRaising', '%ROCapRaising',
       '%SavingCapRaising', 'BookValue', 'CapRaised',
       'Costs', 'ExRightsNo', 'ExtOrdBoardDate',
       'ExtOrdGMInvDate', 'FirstTrade', 'GMType',
       'GenSubsRightsNo', 'LicenseDate', 'MktOfferCloseDate',
       'MktOfferOpenDate', 'NetCashUnEx', 'OnlyRO', 'PremiumCapRaising',
       'ROCapRaising', 'RegDate',
       'SavedDevelopmentPlanCapRaising', 'SavedSafetyCapRaising',
       'SavingCapRaising', 'SubsCloseDate', 'SubsExtendedCloseDate',
       'SubsOpenDate', 'TotUnExRev', 'UnExRightsNo', 'perShareNetCashUnEx']]

# %%
len(df)
# Out:
# 5767

# %%
# ['سرمایه گذاری صنعت و معدن',
# 'موسسه مالی و اعتباری عسکریه',
# 'بانک آریا',
# 'آپادانا سرمایه گذاریم',
# 'امین توان آفرین ساز',
# 'ریسندگی شهرضا',
#  'گسترش تجارت و سرمایه گذاریایه ایرانیان',
# ]

# %%
len(list(set(df[df.Symbol.isnull()]['Firm']))),list(set(df[df.Symbol.isnull()]['Firm']))
# Out:
# (7,
#  ['موسسه مالی و اعتباری عسکریه',
#   'آپادانا سرمایه گذاریم',
#   'بانک آریا',
#   'گسترش تجارت و سرمایه گذاریایه ایرانیان',
#   'سرمایه گذاری صنعت و معدن',
#   'ریسندگی شهرضا',
#   'امین توان آفرین ساز'])

# %%
df.isnull().sum()
# Out:
# Symbol                              17
# year                                 0
# Firm                                25
# CapAfter                             0
# CapBefore                            0
# ExtOrdGMDate                         0
# JustRO                               0
# JustSaving                           0
# JustPremium                          0
# Hybrid                               0
# %CapRaised                          32
# %PremiumCapRaising                  32
# %ROCapRaising                       32
# %SavingCapRaising                   32
# BookValue                           32
# CapRaised                           25
# Costs                             5766
# ExRightsNo                        5763
# ExtOrdBoardDate                   5763
# ExtOrdGMInvDate                   5760
# FirstTrade                        5767
# GMType                              32
# GenSubsRightsNo                   5763
# LicenseDate                       5762
# MktOfferCloseDate                 5763
# MktOfferOpenDate                  5763
# NetCashUnEx                       5766
# OnlyRO                            5760
# PremiumCapRaising                 1853
# ROCapRaising                      1852
# RegDate                           5730
# SavedDevelopmentPlanCapRaising    5763
# SavedSafetyCapRaising             5763
# SavingCapRaising                  1863
# SubsCloseDate                     3152
# SubsExtendedCloseDate             5767
# SubsOpenDate                      5754
# TotUnExRev                        5766
# UnExRightsNo                      5766
# perShareNetCashUnEx               5766
# dtype: int64

# %%
df[(df.Symbol == "شستا")]
# Out:
#      Symbol    year                        Firm    CapAfter   CapBefore  \
# 2459   شستا  1394.0  سرمایه گذاری تامین اجتماعی  39000000.0  39000000.0
# 2460   شستا  1398.0  سرمایه گذاری تامین اجتماعی  80000000.0  39000000.0
#
#       ExtOrdGMDate  JustRO  JustSaving  JustPremium  Hybrid  ...  RegDate  \
# 2459      13940917       0           0            0       1  ...      NaN
# 2460      13980329       1           0            0       0  ...      NaN
#
#       SavedDevelopmentPlanCapRaising  SavedSafetyCapRaising  SavingCapRaising  \
# 2459                             NaN                    NaN               NaN
# 2460                             NaN                    NaN               0.0
#
#       SubsCloseDate  SubsExtendedCloseDate SubsOpenDate TotUnExRev  \
# 2459            NaN                    NaN          NaN        NaN
# 2460     1398/05/29                    NaN          NaN        NaN
#
#      UnExRightsNo perShareNetCashUnEx
# 2459          NaN                 NaN
# 2460          NaN                 NaN
#
# [2 rows x 40 columns]

# %%
df[df.Symbol == 'معیار']
# Out:
#      Symbol    year                          Firm  CapAfter  CapBefore  \
# 3840  معیار  1389.0  سرمایه گذاری معیار صنعت پارس   10000.0     4000.0
# 3841  معیار  1390.0  سرمایه گذاری معیار صنعت پارس   50000.0    10000.0
#
#       ExtOrdGMDate  JustRO  JustSaving  JustPremium  Hybrid  ...  RegDate  \
# 3840      13890615       0           0            0       1  ...      NaN
# 3841      13900504       1           0            0       0  ...      NaN
#
#       SavedDevelopmentPlanCapRaising  SavedSafetyCapRaising  SavingCapRaising  \
# 3840                             NaN                    NaN            613.53
# 3841                             NaN                    NaN              0.00
#
#       SubsCloseDate  SubsExtendedCloseDate SubsOpenDate TotUnExRev  \
# 3840     1389/06/28                    NaN          NaN        NaN
# 3841     1390/05/16                    NaN          NaN        NaN
#
#      UnExRightsNo perShareNetCashUnEx
# 3840          NaN                 NaN
# 3841          NaN                 NaN
#
# [2 rows x 40 columns]

# %%
def vv2(row):
    X = row.split('/')
    return int(X[0]+X[1]+X[2])

df8 = pd.read_excel(r"G:\Hard Data\Capital Raise\\" + "tajdidArzyabi.xlsx", 'all')
df8 = df8.rename(columns = {df8.columns[1]:"RegDate",df8.columns[0]:"Firm"}).drop(columns = df8.columns[2])
df8 = df8[df8.RegDate != 'nan']
df8 = df8[~df8.RegDate.isnull()]
df8 = df8[~df8.Firm.isnull()]
df8['RegDate'] = df8['RegDate'].astype(str)

# %%
def vv2(row):
    X = row.split('/')
    return int(X[0]+X[1]+X[2])

df8 = pd.read_excel(r"G:\Hard Data\Capital Raise\\" + "tajdidArzyabi.xlsx", 'all')
df8 = df8.rename(columns = {df8.columns[1]:"RegDate",df8.columns[0]:"Firm"}).drop(columns = df8.columns[2])
df8 = df8[df8.RegDate != 'nan']
df8 = df8[~df8.RegDate.isnull()]
df8 = df8[~df8.Firm.isnull()]
df8['RegDate'] = df8['RegDate'].astype(str)


df8.RegDate = df8.RegDate.apply(vv2)


ids = symbolfirm.Firm
mapingdict = dict(zip(symbolfirm.Firm, symbolfirm.Symbol))
df8.loc[df8.Firm == 'آذرآب','Firm'] = "آذراب"
df8.loc[df8.Firm == 'آذرآب','Firm'] = "آذراب"
df8.loc[df8.Firm == 'تولید محور خودرو','Firm'] = "محورخودرو"
df8.loc[df8.Firm == 'قند هکمتان','Firm'] = "قندهکمتان‌"



# df8.loc[df8.Firm == '','Firm'] = ""
# df8.loc[df8.Firm == '','Firm'] = ""
# df8.loc[df8.Firm == '','Firm'] = ""
# df8.loc[df8.Firm == '','Firm'] = ""

df8['Firm'] = df8['Firm'].apply(lambda x: convert_ar_characters(x))
df8['Symbol'] = df8['Firm'].map(mapingdict)
index = [34, 35, 36, 37, 38, 39, 40, 41, 42]
df8.loc[df8.index.isin(index),'Symbol'] = df8[df8.index.isin(index)].Firm
df8.loc[df8.Firm == 'کمک فنر ایندامین سایپا','Symbol'] = "خکمک"
df8.loc[df8.Firm == 'کمباین سازی ایران','Symbol'] = "تکمبا"

df8.loc[df8.Firm == ': کشتیرانی جمهوری اسلمی ایران','Symbol'] = "حکشتی"
df8.loc[df8.Firm == ': کاشی تکسرام','Symbol'] = "تکسرام"
df8.loc[df8.Firm == ': قند نیشابور','Symbol'] = "قنیشا"
df8.loc[df8.Firm == ': قند ثابت خراسان','Symbol'] = "قثابت"
df8.loc[df8.Firm == ': شرکت ایرانی تولید اتومبیل )سایپا(','Symbol'] = "خساپا"
df8.loc[df8.Firm == ': گسترش صنایع و خدمات کشاورزی','Symbol'] = "تکشا"
df8.loc[df8.Firm == ': مهندسی صنعتی روان فن آور','Symbol'] = "خفناور"
df8.loc[df8.Firm == 'سرامیک های صنعتی اردکان','Symbol'] = "اردکان"
df8.loc[df8.Firm == ': فرآورده های غذائی و قند تربت جام','Symbol'] = "قجام"
df8.loc[df8.Firm == 'کارخانجات پلسکوکار سایپا','Symbol'] = "پلاسک"
df8.loc[df8.Firm == 'معدنی املح ایران','Symbol'] = "شاملا"
df8.loc[df8.Firm == ': بانک سینا','Symbol'] = "وسینا"
df8.loc[df8.Firm == "قند شیروان، قوچان",'Symbol'] = "قشیر"
df8.loc[df8.Firm == "تامین ماسه ریخته گری",'Symbol'] = "کماسه"
df8.loc[df8.Firm == "فولد کاویان",'Symbol'] = "فوکا"
df8.loc[df8.Firm == "آهنگری تراکتور سازی ایران",'Symbol'] = "خاهن"
df8.loc[df8.Firm == "سهامی ذوب آهن اصفهان",'Symbol'] = "ذوب"
df8.loc[df8.Firm == ": قند بیستون",'Symbol'] = "قیستو"

# df8.loc[df8.Firm == '','Symbol'] = "حکشتی"
df8['year'] = df8.RegDate.astype(str)
df8['year'] = df8['year'].str[0:4]
df8['year'] = df8.year.astype(int)
df8.loc[~df8.symbol.isnull(),'Symbol'] = df8.loc[~df8.symbol.isnull()].symbol
# df8 = df8.dropna()

# %%
df8[df8.Symbol.isnull()]
# Out:
#                                      Firm   RegDate symbol Symbol  year
# 4                             هنکل پاک وش  13910807    NaN    NaN  1391
# 20                                  لحاوی  13920612    NaN    NaN  1392
# 24  گروه کارخانه های تولیدی نورد آلمینیوم  13931227    NaN    NaN  1393

# %%
symbolfirm[symbolfirm.Symbol == 'قیستو']
# Out:
#      Symbol             Firm
# 1027  قیستو       قند بیستون
# 1844  قیستو  شرکت قند بیستون

# %%
fkey = zip(df8.Symbol,df8.year)
len(dict(fkey))
# Out:
# 88

# %%
tt = df8[['Symbol','year']].dropna()
tt
# Out:
#      Symbol  year
# 0      آسیا  1391
# 1     وبملت  1391
# 2     سامان  1391
# 3     وسینا  1391
# 5      خاور  1392
# 6      فاذر  1392
# 7     ونوین  1392
# 8    وتجارت  1392
# 9     البرز  1392
# 10    ورازی  1392
# 11     قشکر  1392
# 12   لبوتان  1392
# 13     فروس  1392
# 14    قصفها  1392
# 15     قشیر  1392
# 16    قزوین  1392
# 17    قهکمت  1392
# 18   فاسمین  1392
# 19    غالبر  1392
# 21    شاملا  1392
# 22     تپکو  1392
# 23    سبزوا  1393
# 25    تکمبا  1393
# 26     خکمک  1393
# 27    حکشتی  1393
# 28   تکسرام  1393
# 29    قنیشا  1393
# 30    قیستو  1393
# 31    قثابت  1393
# 32    خمحور  1393
# ..      ...   ...
# 64    فایرا  1395
# 65     خکار  1395
# 66      ذوب  1395
# 67    خکاوه  1395
# 68    پلاسک  1395
# 69     شپلی  1395
# 70    فبیرا  1397
# 71    شفارا  1397
# 72    سفاسی  1397
# 73    قشرین  1397
# 74  دزهراوی  1397
# 75     ددام  1397
# 76    حفارس  1397
# 77    وسدید  1397
# 78     تپکو  1397
# 79    بایکا  1397
# 80   وتجارت  1397
# 81    شپترو  1397
# 82    ثجوان  1397
# 83    ثنوسا  1397
# 84    چفیبر  1397
# 85     شدوص  1397
# 86    خریخت  1397
# 87     لکما  1397
# 88    خوساز  1397
# 89   وبصادر  1397
# 90      ذوب  1397
# 91    لخانه  1397
# 92     خمهر  1397
# 93     تکنو  1397
#
# [91 rows x 2 columns]

# %%
fkey = zip(tt.Symbol,tt.year)
len(tt)
# Out:
# 91

# %%
fkey = zip(tt.Symbol,tt.year)
mapingdict = dict(zip(fkey,[1] *91 ))
df['year'] = df.year.astype(int)
df['Revaluation'] = df.set_index(['Symbol','year']).index.map(mapingdict)
df.loc[df.Revaluation.isnull(),'Revaluation'] = 0

# %%
df[df.Revaluation == 1]
# Out:
#       Symbol  year                            Firm      CapAfter   CapBefore  \
# 38      آسیا  1391                       بیمه آسیا  4.550000e+05    455000.0
# 137    البرز  1392                      بیمه البرز  6.000000e+05    600000.0
# 138    البرز  1392                      بیمه البرز  3.600000e+06    600000.0
# 195    بالبر  1395                      کابل البرز  1.140000e+05    114000.0
# 196    بالبر  1395                      کابل البرز  2.280000e+05    114000.0
# 197    بالبر  1395                      کابل البرز  2.280000e+05    228000.0
# 198    بالبر  1395                      کابل البرز  3.169200e+05    228000.0
# 208    بایکا  1397                  کابلسازی ایران  3.780000e+04     37800.0
# 209    بایکا  1397                  کابلسازی ایران  5.047342e+05     37800.0
# 491   تمحرکه  1395           ماشین سازی نیرو محرکه  3.250000e+04     32500.0
# 492   تمحرکه  1395           ماشین سازی نیرو محرکه  1.218430e+05     32500.0
# 552     تپکو  1392                            هپکو  3.978000e+05    397800.0
# 553     تپکو  1392                            هپکو  2.336653e+06    397800.0
# 554     تپکو  1397                            هپکو  2.336653e+06   2336653.0
# 555     تپکو  1397                            هپکو  2.112189e+07   2336653.0
# 568     تکشا  1394                   خدمات کشاورزی  3.000000e+04     30000.0
# 569     تکشا  1394                   خدمات کشاورزی  1.099567e+05     30000.0
# 586    تکمبا  1393                     کمباین سازی  5.196860e+05    519686.0
# 587    تکمبا  1393                     کمباین سازی  1.723028e+06    519686.0
# 604     تکنو  1397                         تکنوتار  2.455490e+05    160000.0
# 661    ثجوان  1397               تامین مسکن جوانان  2.000000e+05    200000.0
# 662    ثجوان  1397               تامین مسکن جوانان  2.552513e+06    200000.0
# 759    ثنوسا  1397          نوسازی و ساختمان تهران  7.500000e+05    750000.0
# 760    ثنوسا  1397          نوسازی و ساختمان تهران  2.630000e+06    750000.0
# 857    حفارس  1397  حمل و نقل بین المللی خلیج فارس  3.490000e+05    349000.0
# 858    حفارس  1397  حمل و نقل بین المللی خلیج فارس  2.523904e+06    349000.0
# 882    حکشتی  1393                  کشتیرانی ایران  1.000000e+07  10000000.0
# 883    حکشتی  1393                  کشتیرانی ایران  1.639300e+07  10000000.0
# 895    خاذین  1394                      سایپا آذین  1.000000e+05    100000.0
# 896    خاذین  1394                      سایپا آذین  1.022846e+06    100000.0
# ...      ...   ...                             ...           ...         ...
# 3704  لبوتان  1392                     صنعتی بوتان  7.014520e+05    300000.0
# 3718   لخانه  1397                لوازم خانگی پارس  3.000000e+05    300000.0
# 3719   لخانه  1397                لوازم خانگی پارس  4.481000e+05    300000.0
# 3791    لکما  1397                  مخابراتی ایران  1.401780e+06   1401780.0
# 3792    لکما  1397                  مخابراتی ایران  3.235362e+06   1401780.0
# 4257  وبصادر  1397               بانک صادرات ایران  5.780000e+07  57800000.0
# 4258  وبصادر  1397               بانک صادرات ایران  1.753540e+08  57800000.0
# 4265   وبملت  1391                        بانک ملت  2.000000e+07  20000000.0
# 4266   وبملت  1391                        بانک ملت  3.310000e+07  20000000.0
# 4310  وتجارت  1392                      بانک تجارت  1.750000e+07  17500000.0
# 4311  وتجارت  1392                      بانک تجارت  4.570000e+07  17500000.0
# 4312  وتجارت  1397                      بانک تجارت  4.570000e+07  45700000.0
# 4313  وتجارت  1397                      بانک تجارت  2.239261e+08  45700000.0
# 4416   ورازی  1392                       بیمه رازی  6.258520e+05    280000.0
# 4483   وسدید  1397                 گروه صنعتی سدید  2.000000e+05    200000.0
# 4484   وسدید  1397                 گروه صنعتی سدید  3.980884e+06    200000.0
# 4522    وسین  1393                       بیمه سینا  4.000000e+05    400000.0
# 4532   وسینا  1391                       بانک سینا  4.000000e+06   4000000.0
# 4533   وسینا  1391                       بانک سینا  6.000000e+06   4000000.0
# 4656   ولغدر  1395               لیزینگ خودرو غدیر  5.300000e+05    300000.0
# 4759   ونوین  1392                بانک اقتصاد نوین  8.000000e+06   8000000.0
# 4760   ونوین  1392                بانک اقتصاد نوین  1.131200e+07   8000000.0
# 5076   پلاسک  1395                 پلاسکوکار سایپا  3.880000e+05    388000.0
# 5077   پلاسک  1395                 پلاسکوکار سایپا  9.139386e+05    388000.0
# 5163   چفیبر  1397                      فیبر ایران  2.000000e+05    200000.0
# 5164   چفیبر  1397                      فیبر ایران  1.346925e+06    200000.0
# 5531   کماسه  1394                      تامین ماسه  3.150000e+04     31500.0
# 5532   کماسه  1394                      تامین ماسه  1.620000e+05     31500.0
# 5723   کیسون  1393                           کیسون  1.280000e+06   1280000.0
# 5724   کیسون  1393                           کیسون  3.840000e+06   1280000.0
#
#       ExtOrdGMDate  JustRO  JustSaving  JustPremium  Hybrid  ...  \
# 38        13911226       0           0            0       1  ...
# 137       13920617       0           0            0       1  ...
# 138       13920631       0           1            0       0  ...
# 195       13950309       0           0            0       1  ...
# 196       13950428       1           0            0       0  ...
# 197       13951126       0           0            0       1  ...
# 198       13951210       0           1            0       0  ...
# 208       13971117       0           0            0       1  ...
# 209       13971205       0           1            0       0  ...
# 491       13950519       0           0            0       1  ...
# 492       13950620       0           1            0       0  ...
# 552       13920624       0           0            0       1  ...
# 553       13920715       0           1            0       0  ...
# 554       13971212       0           0            0       1  ...
# 555       13971221       0           1            0       0  ...
# 568       13940319       0           0            0       1  ...
# 569       13940409       0           1            0       0  ...
# 586       13930611       0           0            0       1  ...
# 587       13930626       0           1            0       0  ...
# 604       13971225       0           1            0       0  ...
# 661       13971209       0           0            0       1  ...
# 662       13971213       0           1            0       0  ...
# 759       13971110       0           0            0       1  ...
# 760       13971127       0           1            0       0  ...
# 857       13971212       0           0            0       1  ...
# 858       13971219       0           1            0       0  ...
# 882       13930506       0           0            0       1  ...
# 883       13930615       0           1            0       0  ...
# 895       13941220       0           0            0       1  ...
# 896       13941222       0           1            0       0  ...
# ...            ...     ...         ...          ...     ...  ...
# 3704      13920328       0           1            0       0  ...
# 3718      13971209       0           0            0       1  ...
# 3719      13971219       0           1            0       0  ...
# 3791      13971213       0           0            0       1  ...
# 3792      13971225       0           1            0       0  ...
# 4257      13971214       0           0            0       1  ...
# 4258      13971221       0           1            0       0  ...
# 4265      13910701       0           0            0       1  ...
# 4266      13910702       0           1            0       0  ...
# 4310      13921207       0           0            0       1  ...
# 4311      13921220       0           1            0       0  ...
# 4312      13971223       0           0            0       1  ...
# 4313      13971228       0           1            0       0  ...
# 4416      13920710       0           1            0       0  ...
# 4483      13971212       0           0            0       1  ...
# 4484      13971220       0           1            0       0  ...
# 4522      13931227       0           0            0       1  ...
# 4532      13910419       0           0            0       1  ...
# 4533      13910427       0           1            0       0  ...
# 4656      13950530       0           0            0       1  ...
# 4759      13920716       0           0            0       1  ...
# 4760      13920721       0           1            0       0  ...
# 5076      13950429       0           0            0       1  ...
# 5077      13950430       0           1            0       0  ...
# 5163      13970822       0           0            0       1  ...
# 5164      13970905       0           1            0       0  ...
# 5531      13941006       0           0            0       1  ...
# 5532      13941022       0           1            0       0  ...
# 5723      13930311       0           0            0       1  ...
# 5724      13930326       0           1            0       0  ...
#
#       SavedDevelopmentPlanCapRaising  SavedSafetyCapRaising  SavingCapRaising  \
# 38                               NaN                    NaN               NaN
# 137                              NaN                    NaN               NaN
# 138                              NaN                    NaN      3.000000e+06
# 195                              NaN                    NaN               NaN
# 196                              NaN                    NaN      0.000000e+00
# 197                              NaN                    NaN               NaN
# 198                              NaN                    NaN      8.892000e+04
# 208                              NaN                    NaN               NaN
# 209                              NaN                    NaN      4.669342e+05
# 491                              NaN                    NaN               NaN
# 492                              NaN                    NaN      8.934300e+04
# 552                              NaN                    NaN               NaN
# 553                              NaN                    NaN      1.938853e+06
# 554                              NaN                    NaN               NaN
# 555                              NaN                    NaN      1.878524e+07
# 568                              NaN                    NaN               NaN
# 569                              NaN                    NaN      7.995669e+04
# 586                              NaN                    NaN               NaN
# 587                              NaN                    NaN      1.203342e+06
# 604                              NaN                    NaN      8.554900e+04
# 661                              NaN                    NaN               NaN
# 662                              NaN                    NaN      2.352513e+06
# 759                              NaN                    NaN               NaN
# 760                              NaN                    NaN      1.880000e+06
# 857                              NaN                    NaN               NaN
# 858                              NaN                    NaN      2.174904e+06
# 882                              NaN                    NaN               NaN
# 883                              NaN                    NaN      6.393000e+06
# 895                              NaN                    NaN               NaN
# 896                              NaN                    NaN      9.228464e+05
# ...                              ...                    ...               ...
# 3704                             NaN                    NaN      4.014520e+05
# 3718                             NaN                    NaN               NaN
# 3719                             NaN                    NaN      1.481000e+05
# 3791                             NaN                    NaN               NaN
# 3792                             NaN                    NaN      1.833582e+06
# 4257                             NaN                    NaN               NaN
# 4258                             NaN                    NaN      1.175540e+08
# 4265                             NaN                    NaN               NaN
# 4266                             NaN                    NaN      1.310000e+07
# 4310                             NaN                    NaN               NaN
# 4311                             NaN                    NaN      2.820000e+07
# 4312                             NaN                    NaN               NaN
# 4313                             NaN                    NaN      1.782261e+08
# 4416                             NaN                    NaN      3.458520e+05
# 4483                             NaN                    NaN               NaN
# 4484                             NaN                    NaN      3.780884e+06
# 4522                             NaN                    NaN               NaN
# 4532                             NaN                    NaN               NaN
# 4533                             NaN                    NaN      2.000000e+06
# 4656                             NaN                    NaN      6.494600e+04
# 4759                             NaN                    NaN               NaN
# 4760                             NaN                    NaN      3.312000e+06
# 5076                             NaN                    NaN               NaN
# 5077                             NaN                    NaN      5.259386e+05
# 5163                             NaN                    NaN               NaN
# 5164                             NaN                    NaN      1.146925e+06
# 5531                             NaN                    NaN               NaN
# 5532                             NaN                    NaN      1.305000e+05
# 5723                             NaN                    NaN               NaN
# 5724                             NaN                    NaN      2.560000e+06
#
#       SubsCloseDate  SubsExtendedCloseDate  SubsOpenDate TotUnExRev  \
# 38              NaN                    NaN           NaN        NaN
# 137             NaN                    NaN           NaN        NaN
# 138             NaN                    NaN           NaN        NaN
# 195             NaN                    NaN           NaN        NaN
# 196      1395/07/24                    NaN           NaN        NaN
# 197             NaN                    NaN           NaN        NaN
# 198             NaN                    NaN           NaN        NaN
# 208             NaN                    NaN           NaN        NaN
# 209             NaN                    NaN           NaN        NaN
# 491             NaN                    NaN           NaN        NaN
# 492             NaN                    NaN           NaN        NaN
# 552             NaN                    NaN           NaN        NaN
# 553             NaN                    NaN           NaN        NaN
# 554             NaN                    NaN           NaN        NaN
# 555             NaN                    NaN           NaN        NaN
# 568             NaN                    NaN           NaN        NaN
# 569             NaN                    NaN           NaN        NaN
# 586             NaN                    NaN           NaN        NaN
# 587             NaN                    NaN           NaN        NaN
# 604             NaN                    NaN           NaN        NaN
# 661             NaN                    NaN           NaN        NaN
# 662             NaN                    NaN           NaN        NaN
# 759             NaN                    NaN           NaN        NaN
# 760             NaN                    NaN           NaN        NaN
# 857             NaN                    NaN           NaN        NaN
# 858             NaN                    NaN           NaN        NaN
# 882             NaN                    NaN           NaN        NaN
# 883             NaN                    NaN           NaN        NaN
# 895             NaN                    NaN           NaN        NaN
# 896             NaN                    NaN           NaN        NaN
# ...             ...                    ...           ...        ...
# 3704            NaN                    NaN           NaN        NaN
# 3718            NaN                    NaN           NaN        NaN
# 3719            NaN                    NaN           NaN        NaN
# 3791            NaN                    NaN           NaN        NaN
# 3792            NaN                    NaN           NaN        NaN
# 4257            NaN                    NaN           NaN        NaN
# 4258            NaN                    NaN           NaN        NaN
# 4265            NaN                    NaN           NaN        NaN
# 4266            NaN                    NaN           NaN        NaN
# 4310            NaN                    NaN           NaN        NaN
# 4311            NaN                    NaN           NaN        NaN
# 4312            NaN                    NaN           NaN        NaN
# 4313            NaN                    NaN           NaN        NaN
# 4416            NaN                    NaN           NaN        NaN
# 4483            NaN                    NaN           NaN        NaN
# 4484            NaN                    NaN           NaN        NaN
# 4522            NaN                    NaN           NaN        NaN
# 4532            NaN                    NaN           NaN        NaN
# 4533            NaN                    NaN           NaN        NaN
# 4656     1395/07/29                    NaN           NaN        NaN
# 4759            NaN                    NaN           NaN        NaN
# 4760            NaN                    NaN           NaN        NaN
# 5076            NaN                    NaN           NaN        NaN
# 5077            NaN                    NaN           NaN        NaN
# 5163            NaN                    NaN           NaN        NaN
# 5164            NaN                    NaN           NaN        NaN
# 5531            NaN                    NaN           NaN        NaN
# 5532            NaN                    NaN           NaN        NaN
# 5723            NaN                    NaN           NaN        NaN
# 5724            NaN                    NaN           NaN        NaN
#
#      UnExRightsNo perShareNetCashUnEx Revaluation
# 38            NaN                 NaN         1.0
# 137           NaN                 NaN         1.0
# 138           NaN                 NaN         1.0
# 195           NaN                 NaN         1.0
# 196           NaN                 NaN         1.0
# 197           NaN                 NaN         1.0
# 198           NaN                 NaN         1.0
# 208           NaN                 NaN         1.0
# 209           NaN                 NaN         1.0
# 491           NaN                 NaN         1.0
# 492           NaN                 NaN         1.0
# 552           NaN                 NaN         1.0
# 553           NaN                 NaN         1.0
# 554           NaN                 NaN         1.0
# 555           NaN                 NaN         1.0
# 568           NaN                 NaN         1.0
# 569           NaN                 NaN         1.0
# 586           NaN                 NaN         1.0
# 587           NaN                 NaN         1.0
# 604           NaN                 NaN         1.0
# 661           NaN                 NaN         1.0
# 662           NaN                 NaN         1.0
# 759           NaN                 NaN         1.0
# 760           NaN                 NaN         1.0
# 857           NaN                 NaN         1.0
# 858           NaN                 NaN         1.0
# 882           NaN                 NaN         1.0
# 883           NaN                 NaN         1.0
# 895           NaN                 NaN         1.0
# 896           NaN                 NaN         1.0
# ...           ...                 ...         ...
# 3704          NaN                 NaN         1.0
# 3718          NaN                 NaN         1.0
# 3719          NaN                 NaN         1.0
# 3791          NaN                 NaN         1.0
# 3792          NaN                 NaN         1.0
# 4257          NaN                 NaN         1.0
# 4258          NaN                 NaN         1.0
# 4265          NaN                 NaN         1.0
# 4266          NaN                 NaN         1.0
# 4310          NaN                 NaN         1.0
# 4311          NaN                 NaN         1.0
# 4312          NaN                 NaN         1.0
# 4313          NaN                 NaN         1.0
# 4416          NaN                 NaN         1.0
# 4483          NaN                 NaN         1.0
# 4484          NaN                 NaN         1.0
# 4522          NaN                 NaN         1.0
# 4532          NaN                 NaN         1.0
# 4533          NaN                 NaN         1.0
# 4656          NaN                 NaN         1.0
# 4759          NaN                 NaN         1.0
# 4760          NaN                 NaN         1.0
# 5076          NaN                 NaN         1.0
# 5077          NaN                 NaN         1.0
# 5163          NaN                 NaN         1.0
# 5164          NaN                 NaN         1.0
# 5531          NaN                 NaN         1.0
# 5532          NaN                 NaN         1.0
# 5723          NaN                 NaN         1.0
# 5724          NaN                 NaN         1.0
#
# [160 rows x 41 columns]

# %%
df8[df8.Symbol == 'خمهر']
# Out:
#     Firm   RegDate symbol Symbol  year
# 92  خمهر  13971123   خمهر   خمهر  1397

# %%
df[df.Symbol == 'خمهر'][['Revaluation','year','Symbol','JustSaving']]
# Out:
#       Revaluation  year Symbol  JustSaving
# 1148          0.0  1382   خمهر           0
# 1149          0.0  1384   خمهر           1
# 1150          0.0  1394   خمهر           0
# 1151          0.0  1394   خمهر           0
# 1152          1.0  1397   خمهر           0
# 1153          1.0  1397   خمهر           1

# %%
df.loc[df.Revaluation == 1,'JustRO'] = 0
df.loc[df.Revaluation == 1,'Hybrid'] = 0
df.loc[df.Revaluation == 1,'JustSaving'] = 0
df.loc[df.Revaluation == 1,'JustPremium'] = 0
df.loc[df.Revaluation == 1,'JusHybridtRO'] = 0
df[df.Symbol == 'خمهر'][['Revaluation','year','Symbol','JustSaving']]
# Out:
#       Revaluation  year Symbol  JustSaving
# 1148          0.0  1382   خمهر           0
# 1149          0.0  1384   خمهر           1
# 1150          0.0  1394   خمهر           0
# 1151          0.0  1394   خمهر           0
# 1152          1.0  1397   خمهر           0
# 1153          1.0  1397   خمهر           0

# %%
# datasource = open(r"G:\Hard Data\Capital Raise\\" + 'افزایش سرمایه.xml')
# import xml.etree.ElementTree as ET
# xml_data = open(r"G:\Hard Data\Capital Raise\\" + 'افزایش سرمایه.xml', 'r').read()  # Read file
# root = ET.XML(xml_data)  # Parse XML

# data = []
# cols = []
# for i, child in enumerate(root):
#     data.append([subchild.text for subchild in child])
#     cols.append(child.tag)

# d = pd.DataFrame(data).T  # Write in DF and transpose it
# d.columns = cols  # Update column names
# print(d)

# %%
df.to_excel(r"G:\Hard Data\Capital Raise" + "\Capital Rise - 71-99.xlsx",index = False)

# %%
df.head()
# Out:
#   Symbol  year   Firm  CapAfter  CapBefore  ExtOrdGMDate  JustRO  JustSaving  \
# 0  آ س پ  1388  آ.س.پ  120000.0    60000.0      13881110       1           0
# 1  آ س پ  1389  آ.س.پ  200000.0   120000.0      13891208       1           0
# 2  آ س پ  1392  آ.س.پ  200000.0   200000.0      13921218       0           0
# 3  آ س پ  1393  آ.س.پ  800000.0   200000.0      13930209       1           0
# 4  آ س پ  1397  آ.س.پ  800000.0   800000.0      13970728       0           0
#
#    JustPremium  Hybrid  ...  SavedSafetyCapRaising  SavingCapRaising  \
# 0            0       0  ...                    NaN               0.0
# 1            0       0  ...                    NaN               0.0
# 2            0       1  ...                    NaN               NaN
# 3            0       0  ...                    NaN               0.0
# 4            0       1  ...                    NaN               NaN
#
#    SubsCloseDate  SubsExtendedCloseDate  SubsOpenDate  TotUnExRev  \
# 0            NaN                    NaN           NaN         NaN
# 1            NaN                    NaN           NaN         NaN
# 2            NaN                    NaN           NaN         NaN
# 3     1393/05/12                    NaN           NaN         NaN
# 4            NaN                    NaN           NaN         NaN
#
#   UnExRightsNo perShareNetCashUnEx Revaluation JusHybridtRO
# 0          NaN                 NaN         0.0          NaN
# 1          NaN                 NaN         0.0          NaN
# 2          NaN                 NaN         0.0          NaN
# 3          NaN                 NaN         0.0          NaN
# 4          NaN                 NaN         0.0          NaN
#
# [5 rows x 42 columns]

# %%
df8[df8.Symbol == 'خمهر']
# Out:
#     Firm   RegDate symbol Symbol  year
# 92  خمهر  13971123   خمهر   خمهر  1397

# %%
df[df.Symbol == 'خمهر'][['ExtOrdGMDate',
       'JustRO', 'JustSaving', 'JustPremium', 'Hybrid','Revaluation','year']]
# Out:
#       ExtOrdGMDate  JustRO  JustSaving  JustPremium  Hybrid  Revaluation  year
# 1148      13820106       1           0            0       0          0.0  1382
# 1149      13840408       0           1            0       0          0.0  1384
# 1150      13940415       0           0            0       1          0.0  1394
# 1151      13940525       1           0            0       0          0.0  1394
# 1152      13971123       0           0            0       0          1.0  1397
# 1153      13971205       0           0            0       0          1.0  1397

# %%
df8
# Out:
#                                      Firm   RegDate   symbol   Symbol  year
# 0                               بیمه آسیا  13911226      NaN     آسیا  1391
# 1                                بانک ملت  13910701      NaN    وبملت  1391
# 2                              بانک سامان  13910508      NaN    سامان  1391
# 3                             : بانک سینا  13910419      NaN    وسینا  1391
# 4                             هنکل پاک وش  13910807      NaN      NaN  1391
# 5                        ایران خودرو دیزل  13921220      NaN     خاور  1392
# 6                                   آذراب  13920709      NaN     فاذر  1392
# 7                        بانک اقتصاد نوین  13920716      NaN    ونوین  1392
# 8                              بانک تجارت  13921207      NaN   وتجارت  1392
# 9                              بیمه البرز  13920617      NaN    البرز  1392
# 10                              بیمه رازی  13920620      NaN    ورازی  1392
# 11                             شکر شاهرود  13921001      NaN     قشکر  1392
# 12                            صنعتی بوتان  13920313      NaN   لبوتان  1392
# 13                         فروسیلیس ایران  13921001      NaN     فروس  1392
# 14                             قند اصفهان  13920416      NaN    قصفها  1392
# 15                      قند شیروان، قوچان  13920701      NaN     قشیر  1392
# 16                              قند قزوین  13920319      NaN    قزوین  1392
# 17                             قندهکمتان‌  13921130      NaN    قهکمت  1392
# 18                               کالسیمین  13921203      NaN   فاسمین  1392
# 19                           لبنیات کالبر  13920706      NaN    غالبر  1392
# 20                                  لحاوی  13920612      NaN      NaN  1392
# 21                       معدنی املح ایران  13920619      NaN    شاملا  1392
# 22                                   هپکو  13920624      NaN     تپکو  1392
# 23                       سیمان لار سبزوار  13930728      NaN    سبزوا  1393
# 24  گروه کارخانه های تولیدی نورد آلمینیوم  13931227      NaN      NaN  1393
# 25                      کمباین سازی ایران  13930611      NaN    تکمبا  1393
# 26                 کمک فنر ایندامین سایپا  13931128      NaN     خکمک  1393
# 27          : کشتیرانی جمهوری اسلمی ایران  13930506      NaN    حکشتی  1393
# 28                          : کاشی تکسرام  13931030      NaN   تکسرام  1393
# 29                          : قند نیشابور  13930819      NaN    قنیشا  1393
# ..                                    ...       ...      ...      ...   ...
# 64                        آلومینیوم ایران  13951215      NaN    فایرا  1395
# 65                        ایرکا پارت صنعت  13950329      NaN     خکار  1395
# 66                   سهامی ذوب آهن اصفهان  13951025      NaN      ذوب  1395
# 67                             سایپا دیزل  13950725      NaN    خکاوه  1395
# 68               کارخانجات پلسکوکار سایپا  13950429      NaN    پلاسک  1395
# 69                        پلی اکریل ایران  13951007      NaN     شپلی  1395
# 70                                  فبیرا  13970805    فبیرا    فبیرا  1397
# 71                                  شفارا  13971219    شفارا    شفارا  1397
# 72                                  سفاسی  13971221    سفاسی    سفاسی  1397
# 73                                  قشرین  13971218    قشرین    قشرین  1397
# 74                                دزهراوی  13971212  دزهراوی  دزهراوی  1397
# 75                                   ددام  13971011     ددام     ددام  1397
# 76                                  حفارس  13971212    حفارس    حفارس  1397
# 77                                  وسدید  13971212    وسدید    وسدید  1397
# 78                                   تپکو  13971212     تپکو     تپکو  1397
# 79                                  بایکا  13971117    بایکا    بایکا  1397
# 80                                 وتجارت  13971223   وتجارت   وتجارت  1397
# 81                                  شپترو  13971212    شپترو    شپترو  1397
# 82                                  ثجوان  13971209    ثجوان    ثجوان  1397
# 83                                  ثنوسا  13971110    ثنوسا    ثنوسا  1397
# 84                                  چفیبر  13970822    چفیبر    چفیبر  1397
# 85                                   شدوص  13971011     شدوص     شدوص  1397
# 86                                  خریخت  13971129    خریخت    خریخت  1397
# 87                                   لکما  13971213     لکما     لکما  1397
# 88                                  خوساز  13971002    خوساز    خوساز  1397
# 89                                 وبصادر  13971214   وبصادر   وبصادر  1397
# 90                                    ذوب  13970815      ذوب      ذوب  1397
# 91                                  لخانه  13971209    لخانه    لخانه  1397
# 92                                   خمهر  13971123     خمهر     خمهر  1397
# 93                                   تکنو  13971213     تکنو     تکنو  1397
#
# [94 rows x 5 columns]

# %%
df[df.Revaluation == 1]
# Out:
#       Symbol  year                            Firm      CapAfter   CapBefore  \
# 38      آسیا  1391                       بیمه آسیا  4.550000e+05    455000.0
# 137    البرز  1392                      بیمه البرز  6.000000e+05    600000.0
# 138    البرز  1392                      بیمه البرز  3.600000e+06    600000.0
# 195    بالبر  1395                      کابل البرز  1.140000e+05    114000.0
# 196    بالبر  1395                      کابل البرز  2.280000e+05    114000.0
# 197    بالبر  1395                      کابل البرز  2.280000e+05    228000.0
# 198    بالبر  1395                      کابل البرز  3.169200e+05    228000.0
# 208    بایکا  1397                  کابلسازی ایران  3.780000e+04     37800.0
# 209    بایکا  1397                  کابلسازی ایران  5.047342e+05     37800.0
# 491   تمحرکه  1395           ماشین سازی نیرو محرکه  3.250000e+04     32500.0
# 492   تمحرکه  1395           ماشین سازی نیرو محرکه  1.218430e+05     32500.0
# 552     تپکو  1392                            هپکو  3.978000e+05    397800.0
# 553     تپکو  1392                            هپکو  2.336653e+06    397800.0
# 554     تپکو  1397                            هپکو  2.336653e+06   2336653.0
# 555     تپکو  1397                            هپکو  2.112189e+07   2336653.0
# 568     تکشا  1394                   خدمات کشاورزی  3.000000e+04     30000.0
# 569     تکشا  1394                   خدمات کشاورزی  1.099567e+05     30000.0
# 586    تکمبا  1393                     کمباین سازی  5.196860e+05    519686.0
# 587    تکمبا  1393                     کمباین سازی  1.723028e+06    519686.0
# 604     تکنو  1397                         تکنوتار  2.455490e+05    160000.0
# 661    ثجوان  1397               تامین مسکن جوانان  2.000000e+05    200000.0
# 662    ثجوان  1397               تامین مسکن جوانان  2.552513e+06    200000.0
# 759    ثنوسا  1397          نوسازی و ساختمان تهران  7.500000e+05    750000.0
# 760    ثنوسا  1397          نوسازی و ساختمان تهران  2.630000e+06    750000.0
# 857    حفارس  1397  حمل و نقل بین المللی خلیج فارس  3.490000e+05    349000.0
# 858    حفارس  1397  حمل و نقل بین المللی خلیج فارس  2.523904e+06    349000.0
# 882    حکشتی  1393                  کشتیرانی ایران  1.000000e+07  10000000.0
# 883    حکشتی  1393                  کشتیرانی ایران  1.639300e+07  10000000.0
# 895    خاذین  1394                      سایپا آذین  1.000000e+05    100000.0
# 896    خاذین  1394                      سایپا آذین  1.022846e+06    100000.0
# ...      ...   ...                             ...           ...         ...
# 3704  لبوتان  1392                     صنعتی بوتان  7.014520e+05    300000.0
# 3718   لخانه  1397                لوازم خانگی پارس  3.000000e+05    300000.0
# 3719   لخانه  1397                لوازم خانگی پارس  4.481000e+05    300000.0
# 3791    لکما  1397                  مخابراتی ایران  1.401780e+06   1401780.0
# 3792    لکما  1397                  مخابراتی ایران  3.235362e+06   1401780.0
# 4257  وبصادر  1397               بانک صادرات ایران  5.780000e+07  57800000.0
# 4258  وبصادر  1397               بانک صادرات ایران  1.753540e+08  57800000.0
# 4265   وبملت  1391                        بانک ملت  2.000000e+07  20000000.0
# 4266   وبملت  1391                        بانک ملت  3.310000e+07  20000000.0
# 4310  وتجارت  1392                      بانک تجارت  1.750000e+07  17500000.0
# 4311  وتجارت  1392                      بانک تجارت  4.570000e+07  17500000.0
# 4312  وتجارت  1397                      بانک تجارت  4.570000e+07  45700000.0
# 4313  وتجارت  1397                      بانک تجارت  2.239261e+08  45700000.0
# 4416   ورازی  1392                       بیمه رازی  6.258520e+05    280000.0
# 4483   وسدید  1397                 گروه صنعتی سدید  2.000000e+05    200000.0
# 4484   وسدید  1397                 گروه صنعتی سدید  3.980884e+06    200000.0
# 4522    وسین  1393                       بیمه سینا  4.000000e+05    400000.0
# 4532   وسینا  1391                       بانک سینا  4.000000e+06   4000000.0
# 4533   وسینا  1391                       بانک سینا  6.000000e+06   4000000.0
# 4656   ولغدر  1395               لیزینگ خودرو غدیر  5.300000e+05    300000.0
# 4759   ونوین  1392                بانک اقتصاد نوین  8.000000e+06   8000000.0
# 4760   ونوین  1392                بانک اقتصاد نوین  1.131200e+07   8000000.0
# 5076   پلاسک  1395                 پلاسکوکار سایپا  3.880000e+05    388000.0
# 5077   پلاسک  1395                 پلاسکوکار سایپا  9.139386e+05    388000.0
# 5163   چفیبر  1397                      فیبر ایران  2.000000e+05    200000.0
# 5164   چفیبر  1397                      فیبر ایران  1.346925e+06    200000.0
# 5531   کماسه  1394                      تامین ماسه  3.150000e+04     31500.0
# 5532   کماسه  1394                      تامین ماسه  1.620000e+05     31500.0
# 5723   کیسون  1393                           کیسون  1.280000e+06   1280000.0
# 5724   کیسون  1393                           کیسون  3.840000e+06   1280000.0
#
#       ExtOrdGMDate  JustRO  JustSaving  JustPremium  Hybrid  ...  \
# 38        13911226       0           0            0       0  ...
# 137       13920617       0           0            0       0  ...
# 138       13920631       0           0            0       0  ...
# 195       13950309       0           0            0       0  ...
# 196       13950428       0           0            0       0  ...
# 197       13951126       0           0            0       0  ...
# 198       13951210       0           0            0       0  ...
# 208       13971117       0           0            0       0  ...
# 209       13971205       0           0            0       0  ...
# 491       13950519       0           0            0       0  ...
# 492       13950620       0           0            0       0  ...
# 552       13920624       0           0            0       0  ...
# 553       13920715       0           0            0       0  ...
# 554       13971212       0           0            0       0  ...
# 555       13971221       0           0            0       0  ...
# 568       13940319       0           0            0       0  ...
# 569       13940409       0           0            0       0  ...
# 586       13930611       0           0            0       0  ...
# 587       13930626       0           0            0       0  ...
# 604       13971225       0           0            0       0  ...
# 661       13971209       0           0            0       0  ...
# 662       13971213       0           0            0       0  ...
# 759       13971110       0           0            0       0  ...
# 760       13971127       0           0            0       0  ...
# 857       13971212       0           0            0       0  ...
# 858       13971219       0           0            0       0  ...
# 882       13930506       0           0            0       0  ...
# 883       13930615       0           0            0       0  ...
# 895       13941220       0           0            0       0  ...
# 896       13941222       0           0            0       0  ...
# ...            ...     ...         ...          ...     ...  ...
# 3704      13920328       0           0            0       0  ...
# 3718      13971209       0           0            0       0  ...
# 3719      13971219       0           0            0       0  ...
# 3791      13971213       0           0            0       0  ...
# 3792      13971225       0           0            0       0  ...
# 4257      13971214       0           0            0       0  ...
# 4258      13971221       0           0            0       0  ...
# 4265      13910701       0           0            0       0  ...
# 4266      13910702       0           0            0       0  ...
# 4310      13921207       0           0            0       0  ...
# 4311      13921220       0           0            0       0  ...
# 4312      13971223       0           0            0       0  ...
# 4313      13971228       0           0            0       0  ...
# 4416      13920710       0           0            0       0  ...
# 4483      13971212       0           0            0       0  ...
# 4484      13971220       0           0            0       0  ...
# 4522      13931227       0           0            0       0  ...
# 4532      13910419       0           0            0       0  ...
# 4533      13910427       0           0            0       0  ...
# 4656      13950530       0           0            0       0  ...
# 4759      13920716       0           0            0       0  ...
# 4760      13920721       0           0            0       0  ...
# 5076      13950429       0           0            0       0  ...
# 5077      13950430       0           0            0       0  ...
# 5163      13970822       0           0            0       0  ...
# 5164      13970905       0           0            0       0  ...
# 5531      13941006       0           0            0       0  ...
# 5532      13941022       0           0            0       0  ...
# 5723      13930311       0           0            0       0  ...
# 5724      13930326       0           0            0       0  ...
#
#       SavedSafetyCapRaising  SavingCapRaising  SubsCloseDate  \
# 38                      NaN               NaN            NaN
# 137                     NaN               NaN            NaN
# 138                     NaN      3.000000e+06            NaN
# 195                     NaN               NaN            NaN
# 196                     NaN      0.000000e+00     1395/07/24
# 197                     NaN               NaN            NaN
# 198                     NaN      8.892000e+04            NaN
# 208                     NaN               NaN            NaN
# 209                     NaN      4.669342e+05            NaN
# 491                     NaN               NaN            NaN
# 492                     NaN      8.934300e+04            NaN
# 552                     NaN               NaN            NaN
# 553                     NaN      1.938853e+06            NaN
# 554                     NaN               NaN            NaN
# 555                     NaN      1.878524e+07            NaN
# 568                     NaN               NaN            NaN
# 569                     NaN      7.995669e+04            NaN
# 586                     NaN               NaN            NaN
# 587                     NaN      1.203342e+06            NaN
# 604                     NaN      8.554900e+04            NaN
# 661                     NaN               NaN            NaN
# 662                     NaN      2.352513e+06            NaN
# 759                     NaN               NaN            NaN
# 760                     NaN      1.880000e+06            NaN
# 857                     NaN               NaN            NaN
# 858                     NaN      2.174904e+06            NaN
# 882                     NaN               NaN            NaN
# 883                     NaN      6.393000e+06            NaN
# 895                     NaN               NaN            NaN
# 896                     NaN      9.228464e+05            NaN
# ...                     ...               ...            ...
# 3704                    NaN      4.014520e+05            NaN
# 3718                    NaN               NaN            NaN
# 3719                    NaN      1.481000e+05            NaN
# 3791                    NaN               NaN            NaN
# 3792                    NaN      1.833582e+06            NaN
# 4257                    NaN               NaN            NaN
# 4258                    NaN      1.175540e+08            NaN
# 4265                    NaN               NaN            NaN
# 4266                    NaN      1.310000e+07            NaN
# 4310                    NaN               NaN            NaN
# 4311                    NaN      2.820000e+07            NaN
# 4312                    NaN               NaN            NaN
# 4313                    NaN      1.782261e+08            NaN
# 4416                    NaN      3.458520e+05            NaN
# 4483                    NaN               NaN            NaN
# 4484                    NaN      3.780884e+06            NaN
# 4522                    NaN               NaN            NaN
# 4532                    NaN               NaN            NaN
# 4533                    NaN      2.000000e+06            NaN
# 4656                    NaN      6.494600e+04     1395/07/29
# 4759                    NaN               NaN            NaN
# 4760                    NaN      3.312000e+06            NaN
# 5076                    NaN               NaN            NaN
# 5077                    NaN      5.259386e+05            NaN
# 5163                    NaN               NaN            NaN
# 5164                    NaN      1.146925e+06            NaN
# 5531                    NaN               NaN            NaN
# 5532                    NaN      1.305000e+05            NaN
# 5723                    NaN               NaN            NaN
# 5724                    NaN      2.560000e+06            NaN
#
#       SubsExtendedCloseDate  SubsOpenDate  TotUnExRev UnExRightsNo  \
# 38                      NaN           NaN         NaN          NaN
# 137                     NaN           NaN         NaN          NaN
# 138                     NaN           NaN         NaN          NaN
# 195                     NaN           NaN         NaN          NaN
# 196                     NaN           NaN         NaN          NaN
# 197                     NaN           NaN         NaN          NaN
# 198                     NaN           NaN         NaN          NaN
# 208                     NaN           NaN         NaN          NaN
# 209                     NaN           NaN         NaN          NaN
# 491                     NaN           NaN         NaN          NaN
# 492                     NaN           NaN         NaN          NaN
# 552                     NaN           NaN         NaN          NaN
# 553                     NaN           NaN         NaN          NaN
# 554                     NaN           NaN         NaN          NaN
# 555                     NaN           NaN         NaN          NaN
# 568                     NaN           NaN         NaN          NaN
# 569                     NaN           NaN         NaN          NaN
# 586                     NaN           NaN         NaN          NaN
# 587                     NaN           NaN         NaN          NaN
# 604                     NaN           NaN         NaN          NaN
# 661                     NaN           NaN         NaN          NaN
# 662                     NaN           NaN         NaN          NaN
# 759                     NaN           NaN         NaN          NaN
# 760                     NaN           NaN         NaN          NaN
# 857                     NaN           NaN         NaN          NaN
# 858                     NaN           NaN         NaN          NaN
# 882                     NaN           NaN         NaN          NaN
# 883                     NaN           NaN         NaN          NaN
# 895                     NaN           NaN         NaN          NaN
# 896                     NaN           NaN         NaN          NaN
# ...                     ...           ...         ...          ...
# 3704                    NaN           NaN         NaN          NaN
# 3718                    NaN           NaN         NaN          NaN
# 3719                    NaN           NaN         NaN          NaN
# 3791                    NaN           NaN         NaN          NaN
# 3792                    NaN           NaN         NaN          NaN
# 4257                    NaN           NaN         NaN          NaN
# 4258                    NaN           NaN         NaN          NaN
# 4265                    NaN           NaN         NaN          NaN
# 4266                    NaN           NaN         NaN          NaN
# 4310                    NaN           NaN         NaN          NaN
# 4311                    NaN           NaN         NaN          NaN
# 4312                    NaN           NaN         NaN          NaN
# 4313                    NaN           NaN         NaN          NaN
# 4416                    NaN           NaN         NaN          NaN
# 4483                    NaN           NaN         NaN          NaN
# 4484                    NaN           NaN         NaN          NaN
# 4522                    NaN           NaN         NaN          NaN
# 4532                    NaN           NaN         NaN          NaN
# 4533                    NaN           NaN         NaN          NaN
# 4656                    NaN           NaN         NaN          NaN
# 4759                    NaN           NaN         NaN          NaN
# 4760                    NaN           NaN         NaN          NaN
# 5076                    NaN           NaN         NaN          NaN
# 5077                    NaN           NaN         NaN          NaN
# 5163                    NaN           NaN         NaN          NaN
# 5164                    NaN           NaN         NaN          NaN
# 5531                    NaN           NaN         NaN          NaN
# 5532                    NaN           NaN         NaN          NaN
# 5723                    NaN           NaN         NaN          NaN
# 5724                    NaN           NaN         NaN          NaN
#
#      perShareNetCashUnEx Revaluation JusHybridtRO
# 38                   NaN         1.0          0.0
# 137                  NaN         1.0          0.0
# 138                  NaN         1.0          0.0
# 195                  NaN         1.0          0.0
# 196                  NaN         1.0          0.0
# 197                  NaN         1.0          0.0
# 198                  NaN         1.0          0.0
# 208                  NaN         1.0          0.0
# 209                  NaN         1.0          0.0
# 491                  NaN         1.0          0.0
# 492                  NaN         1.0          0.0
# 552                  NaN         1.0          0.0
# 553                  NaN         1.0          0.0
# 554                  NaN         1.0          0.0
# 555                  NaN         1.0          0.0
# 568                  NaN         1.0          0.0
# 569                  NaN         1.0          0.0
# 586                  NaN         1.0          0.0
# 587                  NaN         1.0          0.0
# 604                  NaN         1.0          0.0
# 661                  NaN         1.0          0.0
# 662                  NaN         1.0          0.0
# 759                  NaN         1.0          0.0
# 760                  NaN         1.0          0.0
# 857                  NaN         1.0          0.0
# 858                  NaN         1.0          0.0
# 882                  NaN         1.0          0.0
# 883                  NaN         1.0          0.0
# 895                  NaN         1.0          0.0
# 896                  NaN         1.0          0.0
# ...                  ...         ...          ...
# 3704                 NaN         1.0          0.0
# 3718                 NaN         1.0          0.0
# 3719                 NaN         1.0          0.0
# 3791                 NaN         1.0          0.0
# 3792                 NaN         1.0          0.0
# 4257                 NaN         1.0          0.0
# 4258                 NaN         1.0          0.0
# 4265                 NaN         1.0          0.0
# 4266                 NaN         1.0          0.0
# 4310                 NaN         1.0          0.0
# 4311                 NaN         1.0          0.0
# 4312                 NaN         1.0          0.0
# 4313                 NaN         1.0          0.0
# 4416                 NaN         1.0          0.0
# 4483                 NaN         1.0          0.0
# 4484                 NaN         1.0          0.0
# 4522                 NaN         1.0          0.0
# 4532                 NaN         1.0          0.0
# 4533                 NaN         1.0          0.0
# 4656                 NaN         1.0          0.0
# 4759                 NaN         1.0          0.0
# 4760                 NaN         1.0          0.0
# 5076                 NaN         1.0          0.0
# 5077                 NaN         1.0          0.0
# 5163                 NaN         1.0          0.0
# 5164                 NaN         1.0          0.0
# 5531                 NaN         1.0          0.0
# 5532                 NaN         1.0          0.0
# 5723                 NaN         1.0          0.0
# 5724                 NaN         1.0          0.0
#
# [160 rows x 42 columns]
